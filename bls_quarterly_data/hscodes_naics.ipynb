# %%
import pandas as pd # need this 
import datetime as dt
import numpy as np

# %% [markdown]
# This notebook will convert HS6 codes to NAICS codes using the census concordance posted [https://www.census.gov/foreign-trade/reference/codes/concordance/expconcord17.xls](https://www.census.gov/foreign-trade/reference/codes/concordance/expconcord17.xls).
#
# This is quite simple, we read in the China list, read in the concordance. Using the concordance we will create a dictionary that will map hs6 codes into naics codes. Then use `.replace` to create the mapping.

# %% [markdown]
# #### Step 1: Read in the tariff data
#
# Note something to be mindful of is the type around the codes. Zeros in front matter here, so setting these as a string is best.

# %%
df50_list = pd.read_excel("tariff_data.xlsx", sheet_name = "$50billion list", dtype = {"HS-8 code": str,"HS6": str})
# This reads it in...

df50_list["time_of_tariff"] = np.nan 
# create an empty column for which we will fill in with the date that the tariff was implemented

df50_list.loc[df50_list["Tariff rate"] == 25,"time_of_tariff"] = dt.datetime(2018,7,6)
# time of the first one

df50_list.loc[df50_list["Tariff rate"] == "25pending","time_of_tariff"] = dt.datetime(2018,8,23)
# time of the second one

df50_list.drop(["Unnamed: 7", "Unnamed: 8"], axis = 1, inplace = True)
# get rid of some columns

df50_list.rename({"2017 Chinese import from the US ($1,000)": "value"}, axis = 1, inplace = True)

df50_list.head(10)
# Out:
#   HS-8 code                                Product description   value  \
# 0  02012000  Fresh or chilled unboned bovine meat ( excl. c...     400
# 1  02013000              Fresh or chilled boneless bovine meat    4658
# 2  02021000           Frozen bovine carcasses & half carcasses       0
# 3  02022000       Frozen unboned bovine meat (excl. carcasses)    1522
# 4  02023000                        Frozen boneless bovine meat   18421
# 5  02031200  Fresh or chilled unboned hams, shoulders & cut...      31
# 6  02031900                  Other fresh or chilled swine meat      15
# 7  02032190       Frozen swine carcasses & half carcasses, nes       0
# 8  02032200  Frozen unboned hams, shoulders & cuts thereof ...  117672
# 9  02032900                            Other frozen swine meat  167924
#
#   Tariff rate     HS6  BEC category BEC description       time_of_tariff
# 0          25  020120           122        Consumer  2018-07-06 00:00:00
# 1          25  020130           122        Consumer  2018-07-06 00:00:00
# 2          25  020210           121    Intermediate  2018-07-06 00:00:00
# 3          25  020220           122        Consumer  2018-07-06 00:00:00
# 4          25  020230           122        Consumer  2018-07-06 00:00:00
# 5          25  020312           122        Consumer  2018-07-06 00:00:00
# 6          25  020319           122        Consumer  2018-07-06 00:00:00
# 7          25  020321           121    Intermediate  2018-07-06 00:00:00
# 8          25  020322           122        Consumer  2018-07-06 00:00:00
# 9          25  020329           122        Consumer  2018-07-06 00:00:00

# %% [markdown]
# Read in the census concordance, for exports, in 2017. Not sure how much variation there is from year to year. This is something that could be checked.

# %%
url = "https://www.census.gov/foreign-trade/reference/codes/concordance/expconcord17.xls"

df_concordance = pd.read_excel(url, dtype = {"commodity": str, "naics": str})

# Again, be mindfull of the types here...

# %%
df_concordance.head()
# Out:
#     commodity                                      descriptn  \
# 0  0101210000                HORSES, PUREBRED BREEDING, LIVE
# 1  0101290000         HORSES, LIVE, EXCEPT PUREBRED BREEDING
# 2  0101300000                                    ASSES, LIVE
# 3  0101900000                        MULES AND HINNIES, LIVE
# 4  0102210010  BOVINES, PUREBRED BREEDING, DAIRY, MALE, LIVE
#
#                                       abbreviatn unit_qy1 unit_qy2   sitc  \
# 0                HORSES, PUREBRED BREEDING, LIVE       NO      NaN  00150
# 1         HORSES, LIVE, EXCEPT PUREBRED BREEDING       NO      NaN  00150
# 2                                    ASSES, LIVE       NO      NaN  00150
# 3                        MULES AND HINNIES, LIVE       NO      NaN  00150
# 4  BOVINES, PUREBRED BREEDING, DAIRY, MALE, LIVE       NO      NaN  00111
#
#    end_use   naics  usda  hitech
# 0    10140  112920     0       0
# 1    10140  112920     0       0
# 2    10140  112920     0       0
# 3    10140  112920     0       0
# 4    10140  11211X     0       0

# %% [markdown]
# The commodity code here is 10digits. We want to create the 8 and 6 digit codes. So we truncate. Note I had difficulty converting the mapping from 8 into NAICS. But the 6 worked

# %%
df_concordance["hs8"] = df_concordance.commodity.str[0:8]

df_concordance["hs6"] = df_concordance.commodity.str[0:6]

# %% [markdown]
# So create a dictionary mapping HS6 codes into naics codes....

# %%
dict_concordance= dict(zip(df_concordance.hs6,df_concordance.naics))

# %% [markdown]
# Then use `.replace` to create the mapping....

# %%
df50_list["naics"] = df50_list.HS6

df50_list["naics"].replace(dict_concordance,value = None,inplace=True)

df50_list.head()
# Out:
#   HS-8 code                                Product description  value  \
# 0  02012000  Fresh or chilled unboned bovine meat ( excl. c...    400
# 1  02013000              Fresh or chilled boneless bovine meat   4658
# 2  02021000           Frozen bovine carcasses & half carcasses      0
# 3  02022000       Frozen unboned bovine meat (excl. carcasses)   1522
# 4  02023000                        Frozen boneless bovine meat  18421
#
#   Tariff rate     HS6  BEC category BEC description       time_of_tariff  \
# 0          25  020120           122        Consumer  2018-07-06 00:00:00
# 1          25  020130           122        Consumer  2018-07-06 00:00:00
# 2          25  020210           121    Intermediate  2018-07-06 00:00:00
# 3          25  020220           122        Consumer  2018-07-06 00:00:00
# 4          25  020230           122        Consumer  2018-07-06 00:00:00
#
#     naics
# 0  311611
# 1  311611
# 2  311611
# 3  311611
# 4  311611

# %% [markdown]
# #### Then do the same thing for the 60 billion list

# %%
df60_list = pd.read_excel("tariff_data.xlsx", sheet_name = "$60billion list", dtype = {"HS-8 code": str,"HS6": str})
# This reads it in...

df60_list["time_of_tariff"] = np.nan 
# create an empty column for which we will fill in with the date that the tariff was implemented

df60_list.loc[:,"time_of_tariff"] = dt.datetime(2018,9,24)

df60_list.rename({"Import value in 2017 ($1,000)": "value"}, axis = 1, inplace = True)

# %%
df60_list.head()
# Out:
#    HS code                             Product description  value  \
# 0  1012900             Live horses, not pure-bred breeding      2
# 1  1061990    Other edible mammals, not pure-bred breeding   3928
# 2  1062090                                   Reptiles, nes    910
# 3  1064990       Other insects, not for pure-bred breeding     35
# 4  1069090  Other live animals, not for pure-bred breeding     59
#
#    Tariff rate     HS6  BEC code  BEC category time_of_tariff
# 0           10  010129       111  Intermediate     2018-09-24
# 1            5  010619       111  Intermediate     2018-09-24
# 2            5  010620       111  Intermediate     2018-09-24
# 3            5  010649       111  Intermediate     2018-09-24
# 4           10  010690       111  Intermediate     2018-09-24

# %%
df60_list["naics"] = df60_list.HS6

df60_list["naics"].replace(dict_concordance,value = None,inplace=True)

df60_list.head()
# Out:
#    HS code                             Product description  value  \
# 0  1012900             Live horses, not pure-bred breeding      2
# 1  1061990    Other edible mammals, not pure-bred breeding   3928
# 2  1062090                                   Reptiles, nes    910
# 3  1064990       Other insects, not for pure-bred breeding     35
# 4  1069090  Other live animals, not for pure-bred breeding     59
#
#    Tariff rate     HS6  BEC code  BEC category time_of_tariff   naics
# 0           10  010129       111  Intermediate     2018-09-24  112920
# 1            5  010619       111  Intermediate     2018-09-24  112990
# 2            5  010620       111  Intermediate     2018-09-24  112990
# 3            5  010649       111  Intermediate     2018-09-24  112990
# 4           10  010690       111  Intermediate     2018-09-24  112990

# %%
df50_list.drop(["value","BEC category","BEC description"],axis = 1, inplace = True)

# %%
df60_list.rename({"HS code":"HS-8 code"},axis = 1,inplace = True)

# %%
df60_list.drop(["value","BEC code","BEC category"],axis = 1, inplace = True)

# %%
tariff_list = df50_list.append(df60_list)

# %%
tariff_list["naics4"] = tariff_list.naics.str[0:4]

# %%
tariff_list.rename({"Tariff rate":"tariff"},axis = 1,inplace = True)

# %%
tariff_list.tariff.replace("25pending",25,inplace = True)

# %%
tariff_list.head()
# Out:
#   HS-8 code                                Product description  tariff  \
# 0  02012000  Fresh or chilled unboned bovine meat ( excl. c...      25
# 1  02013000              Fresh or chilled boneless bovine meat      25
# 2  02021000           Frozen bovine carcasses & half carcasses      25
# 3  02022000       Frozen unboned bovine meat (excl. carcasses)      25
# 4  02023000                        Frozen boneless bovine meat      25
#
#       HS6       time_of_tariff   naics naics4
# 0  020120  2018-07-06 00:00:00  311611   3116
# 1  020130  2018-07-06 00:00:00  311611   3116
# 2  020210  2018-07-06 00:00:00  311611   3116
# 3  020220  2018-07-06 00:00:00  311611   3116
# 4  020230  2018-07-06 00:00:00  311611   3116

# %%
tariff_list.dtypes
# Out:
# HS-8 code              object
# Product description    object
# tariff                  int64
# HS6                    object
# time_of_tariff         object
# naics                  object
# naics4                 object
# dtype: object

# %%
tariff_list.to_csv("tariff_list_naics.csv",index = False)

# %%
tariff_list.groupby("HS6").agg({"tariff":"median", ""})
# Out:
#         tariff
# HS6
# 010129    10.0
# 010619     5.0
# 010620     5.0
# 010649     5.0
# 010690    10.0
# 020120    25.0
# 020130    25.0
# 020210    25.0
# 020220    25.0
# 020230    25.0
# 020312    25.0
# 020319    25.0
# 020321    25.0
# 020322    25.0
# 020329    25.0
# 020422    10.0
# 020629    25.0
# 020641    25.0
# 020649    25.0
# 020712    25.0
# 020713    25.0
# 020714    25.0
# 020725    25.0
# 020727    25.0
# 020742    25.0
# 020745    25.0
# 020910    25.0
# 021011    25.0
# 021012    25.0
# 021019    25.0
# ...        ...
# 960860    10.0
# 960891    10.0
# 960899    10.0
# 960910    10.0
# 960920    10.0
# 960990    10.0
# 961000    10.0
# 961100    10.0
# 961210     5.0
# 961220     5.0
# 961320    10.0
# 961380     5.0
# 961390     5.0
# 961400    10.0
# 961511    10.0
# 961519    10.0
# 961590    10.0
# 961610    10.0
# 961620    10.0
# 961700    10.0
# 961800    10.0
# 961900     5.0
# 962000    10.0
# 970110     7.5
# 970190     5.0
# 970200     5.0
# 970300    10.0
# 970400    10.0
# 970500     5.0
# 970600    10.0
#
# [4210 rows x 1 columns]
