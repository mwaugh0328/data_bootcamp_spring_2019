# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/mwaugh0328/Data_Bootcamp_Fall_2017/master/data_bootcamp_1106/orders_dirty.csv"
#path = "C://data_bootcamp//Data_Bootcamp_Fall_2017//data_bootcamp_1106//orders_dirty.csv"
# Double forward slashes for windows machines.

chp = pd.read_csv(url)

# %%
chp.head(10)
# Out:
#   order store id 1  quantity 2                            item name 3  \
# 0   1 Bucks County           1          Chips and Fresh Tomato Salsa
# 1   1 Bucks County           1                                   Izze
# 2   1 Bucks County           1                       Nantucket Nectar
# 3   1 Bucks County           1  Chips and Tomatillo-Green Chili Salsa
# 4   2 Bucks County           2                           Chicken Bowl
# 5   3 Bucks County           1                           Chicken Bowl
# 6   3 Bucks County           1                          Side of Chips
# 7   4 Bucks County           1                          Steak Burrito
# 8   4 Bucks County           1                       Steak Soft Tacos
# 9   5 Bucks County           1                          Steak Burrito
#
#                                 choice description 4 item price 5
# 0                                                NaN       $2.39
# 1                                       [Clementine]       $3.39
# ...

# %%
chp.dtypes
# Out:
# order store id 1        object
# quantity 2               int64
# item name 3             object
# choice description 4    object
# item price 5            object
# dtype: object

# %%
chp_old_names = list(chp.columns)

# %%
chp_old_names
# Out:
# ['order store id 1',
#  'quantity 2',
#  'item name 3',
#  'choice description 4',
#  'item price 5']

# %%
test_string = 'order store id 1'

# %%
test_string = test_string.replace(" ", "_")

# %%
test_string
# Out:
# 'order_store_id_1'

# %%
new_list = []

for item in chp_old_names:
    new_name = item.replace(" ", "_")
    
    new_list.append(new_name)

# %%
chp.columns = new_list

# %%
chp.head()
# Out:
#   order_store_id_1  quantity_2                            item_name_3  \
# 0   1 Bucks County           1          Chips and Fresh Tomato Salsa
# 1   1 Bucks County           1                                   Izze
# 2   1 Bucks County           1                       Nantucket Nectar
# 3   1 Bucks County           1  Chips and Tomatillo-Green Chili Salsa
# 4   2 Bucks County           2                           Chicken Bowl
#
#                                 choice_description_4 item_price_5
# 0                                                NaN       $2.39
# 1                                       [Clementine]       $3.39
# 2                                            [Apple]       $3.39
# 3                                                NaN       $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      $16.98

# %%
chp.order_store_id_1.unique()
# Out:
# array(['1 Bucks County', '2 Bucks County', '3 Bucks County', ...,
#        '1832 Bucks County', '1833 Bucks County', '1834 Bucks County'],
#       dtype=object)

# %%
chp.shape
# Out:
# (4622, 5)

# %%
unique_obs = pd.DataFrame(chp.order_store_id_1.unique())

# %%
unique_obs.head()
# Out:
#                 0
# 0  1 Bucks County
# 1  2 Bucks County
# 2  3 Bucks County
# 3  4 Bucks County
# 4  5 Bucks County

# %%
unique_obs.shape
# Out:
# (1834, 1)

# %%
chp.order_store_id_1.value_counts()
# Out:
# 926 Bucks County     23
# 1483 Bucks County    14
# 205 Bucks County     12
# 759 Bucks County     11
# 691 Bucks County     11
# 1786 Bucks County    11
# 491 Bucks County     10
# 561 Bucks County      9
# 1660 Bucks County     9
# 953 Bucks County      8
# 1006 Bucks County     8
# 818 Bucks County      8
# 195 Bucks County      8
# 916 Bucks County      8
# 1443 Bucks County     7
# 577 Bucks County      7
# 511 Bucks County      7
# 1449 Bucks County     7
# 628 Bucks County      6
# 1431 Bucks County     6
# 389 Bucks County      6
# 848 Bucks County      6
# 1825 Bucks County     6
# 1586 Bucks County     6
# 1396 Bucks County     6
# 231 Bucks County      6
# 488 Bucks County      6
# 1454 Bucks County     6
# 149 Bucks County      6
# 1156 Bucks County     6
#                      ..
# 932 Bucks County      1
# 741 Bucks County      1
# 871 Bucks County      1
# 1027 Bucks County     1
# 917 Bucks County      1
# 357 Bucks County      1
# 59 Bucks County       1
# ...

# %%
chp[chp.order_store_id_1 == "926 Bucks County"]
# Out:
#       order_store_id_1  quantity_2         item_name_3  \
# 2304  926 Bucks County           1       Steak Burrito
# 2305  926 Bucks County           1        Chicken Bowl
# 2306  926 Bucks County           1        Chicken Bowl
# 2307  926 Bucks County           1        Chicken Bowl
# 2308  926 Bucks County           1          Steak Bowl
# 2309  926 Bucks County           1        Chicken Bowl
# 2310  926 Bucks County           1       Steak Burrito
# 2311  926 Bucks County           1     Chicken Burrito
# 2312  926 Bucks County           1        Chicken Bowl
# 2313  926 Bucks County           1        Chicken Bowl
# 2314  926 Bucks County           1  Chicken Salad Bowl
# 2315  926 Bucks County           1          Steak Bowl
# 2316  926 Bucks County           1     Chicken Burrito
# 2317  926 Bucks County           1          Steak Bowl
# 2318  926 Bucks County           1        Chicken Bowl
# 2319  926 Bucks County           1          Steak Bowl
# ...

# %%
chp.set_index("order_store_id_1").loc["926 Bucks County"]
# Out:
#                   quantity_2         item_name_3  \
# order_store_id_1
# 926 Bucks County           1       Steak Burrito
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1          Steak Bowl
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1       Steak Burrito
# 926 Bucks County           1     Chicken Burrito
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1  Chicken Salad Bowl
# 926 Bucks County           1          Steak Bowl
# 926 Bucks County           1     Chicken Burrito
# 926 Bucks County           1          Steak Bowl
# 926 Bucks County           1        Chicken Bowl
# 926 Bucks County           1          Steak Bowl
# 926 Bucks County           1     Chicken Burrito
# 926 Bucks County           1        Chicken Bowl
# ...

# %%
test = "926 Bucks County"

# %%
test.rsplit()[0]
# Out:
# '926'

# %%
chp.order_store_id_1 = chp.order_store_id_1.str.rsplit().str[0]

# %%
chp.order_store_id_1 = chp.order_store_id_1.astype(int)

# %%
chp.dtypes
# Out:
# order_store_id_1         int32
# quantity_2               int64
# item_name_3             object
# choice_description_4    object
# item_price_5            object
# dtype: object

# %%
chp.head()
# Out:
#    order_store_id_1  quantity_2                            item_name_3  \
# 0                 1           1          Chips and Fresh Tomato Salsa
# 1                 1           1                                   Izze
# 2                 1           1                       Nantucket Nectar
# 3                 1           1  Chips and Tomatillo-Green Chili Salsa
# 4                 2           2                           Chicken Bowl
#
#                                 choice_description_4 item_price_5
# 0                                                NaN       $2.39
# 1                                       [Clementine]       $3.39
# 2                                            [Apple]       $3.39
# 3                                                NaN       $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      $16.98

# %%
chp.set_index("order_store_id_1").loc[926]
# Out:
#                   quantity_2         item_name_3  \
# order_store_id_1
# 926                        1       Steak Burrito
# 926                        1        Chicken Bowl
# 926                        1        Chicken Bowl
# 926                        1        Chicken Bowl
# 926                        1          Steak Bowl
# 926                        1        Chicken Bowl
# 926                        1       Steak Burrito
# 926                        1     Chicken Burrito
# 926                        1        Chicken Bowl
# 926                        1        Chicken Bowl
# 926                        1  Chicken Salad Bowl
# 926                        1          Steak Bowl
# 926                        1     Chicken Burrito
# 926                        1          Steak Bowl
# 926                        1        Chicken Bowl
# 926                        1          Steak Bowl
# 926                        1     Chicken Burrito
# 926                        1        Chicken Bowl
# ...

# %%
uniqe_prices = pd.DataFrame(chp.item_price_5.unique())

# %%
chp.item_price_5.value_counts()
# Out:
# $8.75               725
# $11.25              517
# $9.25               395
# $4.45               348
# $8.49               311
# $11.75              283
# $1.25               264
# $8.99               242
# $2.15               190
# $2.95               174
# $1.50               117
# $1.09               105
# $1.69                99
# $2.39                99
# $10.98               98
# $3.99                96
# $6.49                52
# $11.48               51
# $3.39                45
# $17.50               40
# $2.50                27
# $11.89               26
# $2.18                22
# $8.90                20
# $8.69                19
# $16.98               19
# gift card            19
# $4.30                17
# $9.39                17
# $8.19                14
#                    ...
# manager override      2
# $22.16                2
# $35.00                2
# $6.78                 2
# $6.00                 2
# $27.75                2
# $4.00                 2
# ...

# %%
uniqe_prices.sort_values(by = 0)
# Out:
#                    0
# 13            $1.09
# 23            $1.25
# 27            $1.50
# 4             $1.69
# 79            $1.99
# 71           $10.50
# 32           $10.58
# 3            $10.98
# 26           $11.08
# 9            $11.25
# 18           $11.48
# 80           $11.49
# 5            $11.75
# 51           $11.80
# 39           $11.89
# 68           $12.98
# 58           $13.35
# 74           $13.52
# 76           $15.00
# 73           $16.38
# 2            $16.98
# 20           $17.50
# 78           $17.80
# 19           $17.98
# 36           $18.50
# 15            $2.15
# 11            $2.18
# 44            $2.29
# 0             $2.39
# 33            $2.50
# ..               ...
# 41            $4.00
# 21            $4.30
# 55            $4.36
# 7             $4.45
# 65            $4.50
# 57            $4.78
# 70           $44.25
# 75            $5.00
# 61            $5.07
# 22            $5.90
# 52            $6.00
# 60            $6.45
# 25            $6.49
# ...

# %%
chp.item_price_5.replace(to_replace = "manager override", value = np.nan, inplace = True)

# %%
chp.item_price_5.replace(to_replace = "manager overide", value = np.nan, inplace = True)

# %%
chp.item_price_5.replace(to_replace = "gift card", value = np.nan, inplace = True)

# %%
chp.item_price_5.unique()
# Out:
# array(['$2.39 ', '$3.39 ', '$16.98 ', '$10.98 ', '$1.69 ', '$11.75 ',
#        '$9.25 ', '$4.45 ', '$8.75 ', '$11.25 ', '$8.49 ', '$2.18 ',
#        '$8.99 ', '$1.09 ', '$2.95 ', '$2.15 ', '$3.99 ', '$22.50 ',
#        '$11.48 ', '$17.98 ', '$17.50 ', '$4.30 ', '$5.90 ', '$1.25 ',
#        '$23.78 ', '$6.49 ', '$11.08 ', '$1.50 ', '$22.16 ', '$32.94 ',
#        '$22.20 ', nan, '$10.58 ', '$2.50 ', '$23.50 ', '$7.40 ',
#        '$18.50 ', '$3.00 ', '$6.78 ', '$11.89 ', '$9.39 ', '$4.00 ',
#        '$3.75 ', '$8.69 ', '$2.29 ', '$8.90 ', '$3.27 ', '$3.89 ',
#        '$8.19 ', '$35.00 ', '$27.75 ', '$11.80 ', '$6.00 ', '$26.25 ',
#        '$21.96 ', '$4.36 ', '$7.50 ', '$4.78 ', '$13.35 ', '$6.45 ',
#        '$5.07 ', '$22.96 ', '$7.17 ', '$7.98 ', '$4.50 ', '$26.07 ',
#        '$12.98 ', '$35.25 ', '$44.25 ', '$10.50 ', '$33.75 ', '$16.38 ',
#        '$13.52 ', '$5.00 ', '$15.00 ', '$8.50 ', '$17.80 ', '$1.99 ',
#        '$11.49 '], dtype=object)

# %%
chp.item_price_5 = chp.item_price_5.str.replace("$","")

# %%
chp.item_price_5.unique()
# Out:
# array(['2.39 ', '3.39 ', '16.98 ', '10.98 ', '1.69 ', '11.75 ', '9.25 ',
#        '4.45 ', '8.75 ', '11.25 ', '8.49 ', '2.18 ', '8.99 ', '1.09 ',
#        '2.95 ', '2.15 ', '3.99 ', '22.50 ', '11.48 ', '17.98 ', '17.50 ',
#        '4.30 ', '5.90 ', '1.25 ', '23.78 ', '6.49 ', '11.08 ', '1.50 ',
#        '22.16 ', '32.94 ', '22.20 ', nan, '10.58 ', '2.50 ', '23.50 ',
#        '7.40 ', '18.50 ', '3.00 ', '6.78 ', '11.89 ', '9.39 ', '4.00 ',
#        '3.75 ', '8.69 ', '2.29 ', '8.90 ', '3.27 ', '3.89 ', '8.19 ',
#        '35.00 ', '27.75 ', '11.80 ', '6.00 ', '26.25 ', '21.96 ', '4.36 ',
#        '7.50 ', '4.78 ', '13.35 ', '6.45 ', '5.07 ', '22.96 ', '7.17 ',
#        '7.98 ', '4.50 ', '26.07 ', '12.98 ', '35.25 ', '44.25 ', '10.50 ',
#        '33.75 ', '16.38 ', '13.52 ', '5.00 ', '15.00 ', '8.50 ', '17.80 ',
#        '1.99 ', '11.49 '], dtype=object)

# %%
chp.item_price_5 = chp.item_price_5.astype(float)

# %%
chp.dtypes
# Out:
# order_store_id_1          int32
# quantity_2                int64
# item_name_3              object
# choice_description_4     object
# item_price_5            float64
# dtype: object

# %%
chp.head()
# Out:
#    order_store_id_1  quantity_2                            item_name_3  \
# 0                 1           1          Chips and Fresh Tomato Salsa
# 1                 1           1                                   Izze
# 2                 1           1                       Nantucket Nectar
# 3                 1           1  Chips and Tomatillo-Green Chili Salsa
# 4                 2           2                           Chicken Bowl
#
#                                 choice_description_4  item_price_5
# 0                                                NaN          2.39
# 1                                       [Clementine]          3.39
# 2                                            [Apple]          3.39
# 3                                                NaN          2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         16.98

# %%
chp.set_index("order_store_id_1").loc[926].item_price_5.sum()
# Out:
# 205.25
