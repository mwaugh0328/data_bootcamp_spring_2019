# %%
import geopandas as gpd # this is the main geopandas 
from shapely.geometry import Point, Polygon # also needed

import pandas as pd # Key tool 
import matplotlib.pyplot as plt # Helps plot
import numpy as np # Numerical operations
import os

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
type(world)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %%
world.loc[1,"geometry"]

# %%
x, y = world.loc[1,"geometry"].exterior.coords.xy

# %%
print(len(x))
# Out:
# 52

# %%
x
# Out:
# array('d', [33.90371119710453, 34.07261999999997, 37.69868999999994, 37.7669, 39.20222, 38.74053999999995, 38.79977000000008, 39.44, 39.47000000000014, 39.19468999999998, 39.25203000000005, 39.18652000000009, 39.53574000000009, 39.94960000000003, 40.316586229110854, 40.31659000000002, 39.52099999999996, 38.42755659358775, 37.827639999999974, 37.471289999999954, 36.775150994622805, 36.51408165868426, 35.31239790216904, 34.55998904799935, 34.27999999999997, 33.940837724096525, 33.73972000000009, 32.75937544122132, 32.19186486179194, 31.556348097466497, 31.15775133695005, 30.740009731422095, 30.74001549655179, 30.199996779101696, 29.620032179490014, 29.419992710088167, 29.519986606572928, 29.339997592900346, 29.753512404099865, 30.11632000000003, 30.505539999999996, 30.752240000000086, 30.743010000000027, 30.527660000000026, 30.469673645761223, 30.469670000000008, 30.75830895358311, 30.816134881317712, 30.419104852019245, 30.769860000000108, 31.866170000000068, 33.90371119710453])

# %%
y
# Out:
# array('d', [-0.9500000000000001, -1.0598199999999451, -3.0969899999999484, -3.6771200000000004, -4.67677, -5.9089499999999475, -6.475660000000005, -6.839999999999861, -7.099999999999966, -7.703899999999976, -8.00780999999995, -8.48550999999992, -9.112369999999885, -10.098400000000026, -10.317097752817492, -10.317099999999868, -10.89688000000001, -11.285202325081656, -11.26878999999991, -11.568759999999997, -11.594537448780805, -11.720938002166735, -11.439146416879147, -11.520020033415925, -10.160000000000025, -9.693673841980285, -9.417149999999992, -9.23059905358906, -8.930358981973257, -8.762048841998642, -8.594578747317366, -8.34000593035372, -8.340007419470915, -7.079980970898163, -6.520015150583426, -5.939998874539434, -5.419978936386315, -4.4999834122940925, -4.452389418153302, -4.090120000000013, -3.5685799999999404, -3.3593099999999936, -3.034309999999948, -2.807619999999986, -2.41385475710134, -2.4138299999999617, -2.2872502579883687, -1.6989140763453887, -1.1346591121504161,
# ...

# %%
fig, ax = plt.subplots(figsize = (10,10))

world[world["continent"]=="Africa"].plot(ax = ax, edgecolor = "k", color = "white")

# %%
world[world["continent"]=="South America"]
# Out:
#        pop_est      continent          name iso_a3  gdp_md_est  \
# 9     44293293  South America     Argentina    ARG    879400.0
# 10    17789267  South America         Chile    CHL    436100.0
# 20        2931  South America  Falkland Is.    FLK       281.8
# 28     3360148  South America       Uruguay    URY     73250.0
# 29   207353391  South America        Brazil    BRA   3081000.0
# 30    11138234  South America       Bolivia    BOL     78350.0
# 31    31036656  South America          Peru    PER    410400.0
# 32    47698524  South America      Colombia    COL    688000.0
# 40    31304016  South America     Venezuela    VEN    468600.0
# 41      737718  South America        Guyana    GUY      6093.0
# 42      591919  South America      Suriname    SUR      8547.0
# 44    16290913  South America       Ecuador    ECU    182400.0
# 156    6943739  South America      Paraguay    PRY     64670.0
#
#                                               geometry
# ...

# %%
cwd = os.getcwd()

# %%
shape_file = cwd + "\\shape_file\\ZIP_CODE_040114.shx"

# %%
shape_file
# Out:
# 'C:\\GitHub\\data_bootcamp_spring_2019\\mapping\\shape_file\\ZIP_CODE_040114.shx'

# %%
nyc_map = gpd.read_file(shape_file)

# %%
nyc_map.head()
# Out:
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  POLYGON ((1001613.712964058 186926.4395172149,...
# ...

# %%
nyc_map.dtypes
# Out:
# ZIPCODE        object
# BLDGZIP        object
# PO_NAME        object
# POPULATION    float64
# AREA          float64
# STATE          object
# COUNTY         object
# ST_FIPS        object
# CTY_FIPS       object
# URL            object
# SHAPE_AREA    float64
# SHAPE_LEN     float64
# geometry       object
# dtype: object

# %%
fig, ax = plt.subplots(figsize = (10,10))

nyc_map.plot(ax = ax, edgecolor = 'k', color = "white")

# %%
fig, ax = plt.subplots(figsize = (10,10))

nyc_map.plot(ax = ax, 
             column = "POPULATION",
             edgecolor = 'k',
             cmap='RdBu_r',
             vmin=0, vmax=nyc_map.POPULATION.max())

plt.show()
